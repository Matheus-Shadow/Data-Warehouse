# %%
import pandas as pd
import logging
import os
import sys
from dotenv import load_dotenv

# %%
sys.path.insert(1, r'Q:\04 - PROJETOS\DW\Data-Warehouse\Func')
from utils2 import clear_env_variables, load_env, connect_to_database, execute_query_sql

# %%
if __name__ == "__main__":
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    def process_query(env_file_path, query_file_path):
        # Limpar variáveis de ambiente anteriores, se houver
        clear_env_variables()
        
        # Carregar variáveis de ambiente do .env
        env_vars = load_env(env_file_path)
        
        # Verificar se todas as variáveis de ambiente necessárias foram carregadas
        required_vars = ['SERVER', 'DATABASE', 'USERNAME', 'PASSWORD', 'DRIVER', 'PORT']
        if all([env_vars.get(var) for var in required_vars]):
            # Conectar ao banco de dados usando as variáveis do .env
            conn = connect_to_database(env_vars)
            
            if conn:
                try:
                    # Executar a consulta SQL e obter o DataFrame
                    df = execute_query_sql(conn, query_file_path)
                    
                    # Desconectar do banco de dados
                    conn.close()
                    
                    logging.info(f"DataFrame criado com {len(df)} linhas.")
                    return df
                
                except Exception as e:
                    logging.error(f"Erro ao executar a consulta SQL: {str(e)}")
                    return pd.DataFrame()  # Gerar DataFrame vazio em caso de erro na consulta
            else:
                logging.error("Falha na conexão ao banco de dados.")
                return pd.DataFrame()  # Gerar DataFrame vazio se a conexão falhar
        else:
            logging.error("Erro: Não foi possível carregar todas as variáveis de ambiente necessárias.")
            return pd.DataFrame()  # Gerar DataFrame vazio se as variáveis de ambiente não forem carregadas corretamente

    # Defina os caminhos para os arquivos .env e SQL
    env_file_paths_Env_18 = [
        r'Q:\04 - PROJETOS\DW\Data-Warehouse\Environment\.Env_18']
    query_file_path_ACIONA_CRM = r'X:\04 - PROJETOS\DW\Data-Warehouse\Source\2CX\ACIONA_DISCADOR_OUTBOUND\ACIONA_DISCADOR_ATIVO_BD_1.SQL'

    # Processar cada conjunto de arquivos .env e SQL
    dfs = [process_query(env_file_path, query_file_path_ACIONA_CRM) for env_file_path in env_file_paths_Env_18]

    # Inicialize combined_df como um DataFrame vazio
    combined_df = pd.DataFrame()
# Out:
# 2024-07-30 21:29:25,995 - INFO - Variáveis de ambiente carregadas: {'SERVER': '10.10.228.155', 'DATABASE': 'DF_MFDIGITAL', 'USERNAME': 'mis', 'PASSWORD': 'MIS@MFD#1907', 'DRIVER': '{ODBC Driver 17 for SQL Server}', 'PORT': '1433'}
# 2024-07-30 21:29:26,127 - ERROR - Erro ao conectar ao banco de dados: ('28000', '[28000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Login failed for user \'mis\'. (18456) (SQLDriverConnect); [28000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Cannot open database "DF_MFDIGITAL" requested by the login. The login failed. (4060); [28000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Login failed for user \'mis\'. (18456); [28000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Cannot open database "DF_MFDIGITAL" requested by the login. The login failed. (4060)')
# 2024-07-30 21:29:26,128 - ERROR - Falha na conexão ao banco de dados.

# %%
 # Inicialize combined_df como um DataFrame vazio
combined_df = pd.DataFrame()

# Iterar sobre a lista de DataFrames e concatená-los
for df in dfs:
    if not df.empty:
         if combined_df.empty:
                combined_df = df  # Se combined_df estiver vazio, defina-o como o primeiro DataFrame não vazio
         else:
             combined_df = pd.concat([combined_df, df], ignore_index=True)  # Concatene com o DataFrame existente

    # Exibir o DataFrame combinado
    logging.info(f"DataFrame combinado criado com {len(combined_df)} linhas.")
    display(combined_df)  # Exibir o DataFrame combinado
# Out:
# 2024-07-25 15:13:40,622 - INFO - DataFrame combinado criado com 10 linhas.
#        CallId  Agentld  Campaignld  Dispositionld               StartDate  \
# 0  1910505215        0         352              8 2024-06-26 13:50:23.597
# 1  1910505219        0         352              8 2024-06-26 13:50:23.597
# 2  1910505220        0         352              8 2024-06-26 13:50:23.597
# 3  1910505222        0         352              8 2024-06-26 13:50:23.597
# 4  1910505223        0         352              8 2024-06-26 13:50:23.597
# 5  1910505224        0         352              8 2024-06-26 13:50:23.597
# 6  1910505228        0         352              8 2024-06-26 13:50:23.627
# 7  1910505229        0         352              8 2024-06-26 13:50:23.627
# 8  1910505231        0         352              8 2024-06-26 13:50:23.630
# 9  1910505239        0         352              8 2024-06-26 13:50:23.630
#
#                   EndWrap                                        TableName  \
# 0 2024-06-26 13:50:41.457  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 1 2024-06-26 13:50:38.610  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 2 2024-06-26 13:50:38.307  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 3 2024-06-26 13:50:37.667  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 4 2024-06-26 13:50:38.743  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 5 2024-06-26 13:50:37.837  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 6 2024-06-26 13:50:37.773  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 7 2024-06-26 13:50:40.857  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 8 2024-06-26 13:50:39.623  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
# 9 2024-06-26 13:50:37.360  AD_TIM_MAILING_EXT_DIGITAL_CT_LOTENOVO_20240626
#
#                   EndCall OriginalPhoneNumber            Dnis  PhoneTypeld  \
# 0 2024-06-26 13:50:41.457         61982328244  04161982328244            9
# 1 2024-06-26 13:50:38.610         34991181918  04134991181918            9
# 2 2024-06-26 13:50:38.307         19982983586  04119982983586            9
# 3 2024-06-26 13:50:37.667         41997764845  04141997764845            9
# 4 2024-06-26 13:50:38.743         81999767778  04181999767778            9
# 5 2024-06-26 13:50:37.837         35992433704  04135992433704            9
# 6 2024-06-26 13:50:37.773         87996015410  04187996015410            9
# 7 2024-06-26 13:50:40.857         21986209350  04121986209350            9
# 8 2024-06-26 13:50:39.623         41999588494  04141999588494            9
# 9 2024-06-26 13:50:37.360         24981148106  04124981148106            9
#
#       Route                                       CampaignData   Customerld  \
# 0  SBC1_TIM  <Prefix>61</Prefix><CustomerNameRecord></Custo...  21577099320
# 1  SBC1_TIM  <Prefix>34</Prefix><CustomerNameRecord></Custo...  51733072691
# 2  SBC1_TIM  <Prefix>19</Prefix><CustomerNameRecord></Custo...  31168296838
# 3  SBC1_TIM  <Prefix>41</Prefix><CustomerNameRecord></Custo...  08357969909
# 4  SBC1_TIM  <Prefix>81</Prefix><CustomerNameRecord></Custo...  03479753485
# 5  SBC1_TIM  <Prefix>35</Prefix><CustomerNameRecord></Custo...  07416666694
# 6  SBC1_TIM  <Prefix>87</Prefix><CustomerNameRecord></Custo...  00503791512
# 7  SBC1_TIM  <Prefix>21</Prefix><CustomerNameRecord></Custo...  93633599720
# 8  SBC1_TIM  <Prefix>41</Prefix><CustomerNameRecord></Custo...  47863749972
# 9  SBC1_TIM  <Prefix>24</Prefix><CustomerNameRecord></Custo...  17986686707
#
#    MailingRecordld  MailingPhoneNumberld     CallIdTelecom  AttemptsRawDataID
# 0            89309                127722  0019856c2c2c5428         1854874257
# 1            89654                128221  0019858c2c2c5428         1854874258
# 2            89711                128305  001985782c2c5428         1854874259
# 3            89517                128010  001984dd2c2c5428         1854874260
# 4            89349                127779  001984d32c2c5428         1854874261
# 5            89530                128031  001985882c2c5428         1854874262
# 6            89499                127986  001983e02c2c5428         1854874263
# 7            89798                128422  001983cd2c2c5428         1854874264
# 8            89514                128006  001984d92c2c5428         1854874265
# 9            89727                128326  0019858e2c2c5428         1854874266
